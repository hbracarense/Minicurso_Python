# %% [markdown]
# 1) Importe o arquivo ‘base_temp.xlsx’ para um dataframe pandas.

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path_abs = '/content/drive/My Drive'
path_base = '/Curso de Python/Bases/base_temp.xlsx'
path_cod = '/Curso de Python/Bases/codigos_mun.xlsx'

# %%
df = pd.read_excel(path_abs+path_base)
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    id_domicilio  zona  municipio  num_moradores  comodos  banheiros  som  tv  \
# 0             1     2          1              9        3          2    0   0
# 1             2     2          1              6        5          1    0   1
# 2             3     2          1              7        4          1    0   1
# 3             4     2          1              3        5          2    1   1
# 4             5     2          1              4        4          2    0   1
#
#    dvd  geladeira  ...  mes_malaria  dia_malaria  internacao  grupo_data  \
# 0    0          1  ...          1.0          NaN         1.0           1
# 1    0          1  ...          1.0          NaN         0.0           1
# ...

# %% [markdown]
# 2) Importe o arquivo ‘codigos_mun.xlsx’, na aba ‘c1’, para um dataframe pandas.

# %%
df_cod1 = pd.read_excel(path_abs+path_cod, sheet_name='c1')
df_cod1.head()
# Out:
#    codigo              cidade
# 0       1  Candeias do Jamari
# 1       2               Cantá
# 2       3           Caracaraí
# 3       4     Cruzeiro do Sul
# 4       5             Ipixuna

# %% [markdown]
# 3) Faça um left join entre ambos os dataframes, formando um novo dataframe.

# %%
df1 = df.merge(df_cod1, left_on = 'municipio', right_on = 'codigo', how = 'left')
df1.head()
# Out:
#    id_domicilio  zona  municipio  num_moradores  comodos  banheiros  som  tv  \
# 0             1     2          1              9        3          2    0   0
# 1             2     2          1              6        5          1    0   1
# 2             3     2          1              7        4          1    0   1
# 3             4     2          1              3        5          2    1   1
# 4             5     2          1              4        4          2    0   1
#
#    dvd  geladeira  ...  internacao  grupo_data  multiplos_beneficios  \
# 0    0          1  ...         1.0           1                   0.0
# 1    0          1  ...         0.0           1                   0.0
# 2    0          1  ...         0.0           2                   NaN
# 3    1          1  ...         0.0           1                   1.0
# 4    0          0  ...         0.0           1                   0.0
#
#    multiplos_tratamentos  configuracao_familiar  trimestre_malaria  uf  \
# ...

# %%
df1.shape
# Out:
# (1327, 151)

# %% [markdown]
# 4) Informe quantos registros tem o dataframe formado por domicílios em Cantá ou Caracarai.

# %%
print(len(df1[df1.cidade.isin(['Cantá', 'Caracaraí'])]))
# Out:
# 182

# %% [markdown]
# 5) Agora, faça um left Join do dataframe original de base_temp com o dataframe do arquivo ‘codigos_mun.xlsx’ na aba ‘c2’.

# %%
df_cod2 = pd.read_excel(path_abs+path_cod, sheet_name = 'c2')
df_cod2.head()
# Out:
#    codigo              cidade
# 0       1  Candeias do Jamari
# 1       2               Cantá
# 2       3           Caracaraí
# 3       4     Cruzeiro do Sul

# %%
df2 = df.merge(df_cod2, left_on = 'municipio', right_on = 'codigo', how = 'left')
df2.head()
# Out:
#    id_domicilio  zona  municipio  num_moradores  comodos  banheiros  som  tv  \
# 0             1     2          1              9        3          2    0   0
# 1             2     2          1              6        5          1    0   1
# 2             3     2          1              7        4          1    0   1
# 3             4     2          1              3        5          2    1   1
# 4             5     2          1              4        4          2    0   1
#
#    dvd  geladeira  ...  internacao  grupo_data  multiplos_beneficios  \
# 0    0          1  ...         1.0           1                   0.0
# 1    0          1  ...         0.0           1                   0.0
# 2    0          1  ...         0.0           2                   NaN
# 3    1          1  ...         0.0           1                   1.0
# 4    0          0  ...         0.0           1                   0.0
#
#    multiplos_tratamentos  configuracao_familiar  trimestre_malaria  uf  \
# ...

# %% [markdown]
# 6) Elimine todas as linhas em que cidade for NaN e informe quantas linhas tem o dataframe resultante.

# %%
df2 = df2.dropna(subset = ['cidade'])
print(len(df2))
# Out:
# 659
